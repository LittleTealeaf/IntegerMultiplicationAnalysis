# %%
import pandas as pd

data = pd.read_csv('results.csv')

data
# Out:
#       digits       Default     Karatsuba         Java
# 0        2.0  1.852000e+03  1.955000e+03      2797.88
# 1        3.0  2.228000e+03  2.426000e+03      2384.89
# 2        4.0  2.210070e+03  2.581980e+03      2866.07
# 3        6.0  2.294990e+03  2.350880e+03      2320.03
# 4        9.0  2.919960e+03  3.182010e+03      1950.07
# 5       13.0  3.324090e+03  1.771060e+03      4334.01
# 6       19.0  3.040950e+03  1.589408e+04      3033.02
# 7       28.0  2.242980e+03  3.548898e+04      3858.93
# 8       42.0  6.820020e+03  6.926907e+04      6710.05
# 9       63.0  3.097120e+03  4.666898e+04      3972.87
# 10      94.0  1.696807e+04  2.379539e+05      2527.02
# 11     141.0  1.705408e+04  1.680590e+05     25200.07
# 12     211.0  5.955806e+04  1.475002e+06      7753.99
# 13     316.0  5.789080e+03  8.661700e+05    289325.03
# 14     474.0  1.334812e+04  4.283220e+06   1247454.98
# 15     711.0  6.299704e+04  5.124057e+06     26889.04
# ...

# %% [markdown]
# ## Mapping to seconds

# %%
data[['Default','Karatsuba','Java']].applymap(lambda x: x * 1e-9)
data
# Out:
#       digits       Default     Karatsuba         Java
# 0        2.0  1.852000e+03  1.955000e+03      2797.88
# 1        3.0  2.228000e+03  2.426000e+03      2384.89
# 2        4.0  2.210070e+03  2.581980e+03      2866.07
# 3        6.0  2.294990e+03  2.350880e+03      2320.03
# 4        9.0  2.919960e+03  3.182010e+03      1950.07
# 5       13.0  3.324090e+03  1.771060e+03      4334.01
# 6       19.0  3.040950e+03  1.589408e+04      3033.02
# 7       28.0  2.242980e+03  3.548898e+04      3858.93
# 8       42.0  6.820020e+03  6.926907e+04      6710.05
# 9       63.0  3.097120e+03  4.666898e+04      3972.87
# 10      94.0  1.696807e+04  2.379539e+05      2527.02
# 11     141.0  1.705408e+04  1.680590e+05     25200.07
# 12     211.0  5.955806e+04  1.475002e+06      7753.99
# 13     316.0  5.789080e+03  8.661700e+05    289325.03
# 14     474.0  1.334812e+04  4.283220e+06   1247454.98
# 15     711.0  6.299704e+04  5.124057e+06     26889.04
# ...

# %%
import matplotlib.pyplot as plt

data.plot(x='digits',y=['Default','Karatsuba','Java'])
# Out:
# <AxesSubplot:xlabel='digits'>
