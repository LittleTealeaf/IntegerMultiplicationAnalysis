# %%
import pandas as pd

data = pd.read_csv('results.csv')
data[['Default','Karatsuba','Java']].applymap(lambda x: x * 1e-9)
data
# Out:
#       Digits      Default    Karatsuba        Java
# 0        2.0       2212.0       2294.0      2774.0
# 1        3.0       2194.0       2553.0      2332.0
# 2        4.0       2523.0       2799.0      2513.0
# 3        5.0       2722.0       5283.0      3065.0
# 4        6.0       2671.0       3266.0      5968.0
# ..       ...          ...          ...         ...
# 96   64322.0  261068006.0  486256577.0  15588369.0
# 97   70755.0  315282901.0  539414894.0  12905370.0
# 98   77831.0  369083902.0  731169768.0  17193244.0
# 99   85615.0  455200015.0  773069922.0  12394964.0
# 100  94177.0  526059598.0  909150721.0  13907968.0
#
# [101 rows x 4 columns]

# %%
data.plot(x='Digits',y=['Default','Karatsuba','Java'],title="Time Spent vs Digit Count",ylabel="Time (seconds)")
data.plot(x='Digits',y=['Default','Karatsuba','Java'],title="Log Time Spent vs Log Digit Count",ylabel="Log Time (log(seconds))",xlabel="Log Digits (log(seconds))",loglog=True)
# Out:
# <AxesSubplot:title={'center':'Log Time Spent vs Log Digit Count'}, xlabel='Log Digits (log(seconds))', ylabel='Log Time (log(seconds))'>
