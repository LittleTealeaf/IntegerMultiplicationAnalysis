# %%
import pandas as pd

data = pd.read_csv('results.csv')
data[['Default','Karatsuba','Java']] = data[['Default','Karatsuba','Java']] * 1e-9
data
# Out:
#        Digits    Default  Karatsuba      Java
# 0         2.0   0.000002   0.000002  0.000003
# 1         3.0   0.000002   0.000003  0.000003
# 2         4.0   0.000003   0.000003  0.000004
# 3         5.0   0.000002   0.000004  0.000004
# 4         6.0   0.000003   0.000003  0.000002
# ..        ...        ...        ...       ...
# 113  325136.0   5.582375   6.639571  0.106812
# 114  357650.0   6.731186   4.889375  0.161105
# 115  393416.0   8.394199   5.061544  0.133298
# 116  432758.0   9.969092   5.351515  0.198213
# 117  476034.0  12.019189   6.594071  0.213615
#
# [118 rows x 4 columns]

# %%
data.plot(x='Digits',y=['Default','Karatsuba','Java'],title="Time Spent vs Digit Count",ylabel="Time (seconds)")
data.plot(x='Digits',y=['Default','Karatsuba','Java'],title="Log Time Spent vs Log Digit Count",ylabel="Log Time (log(seconds))",xlabel="Log Digits (log(seconds))",loglog=True)
# Out:
# <AxesSubplot:title={'center':'Log Time Spent vs Log Digit Count'}, xlabel='Log Digits (log(seconds))', ylabel='Log Time (log(seconds))'>
